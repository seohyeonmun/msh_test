# %%
# 실무사용팁!
# 프로젝트를 개발하다보면 버전충돌문제가 발생할 수 있음
# 다른 팀원이 내 코드를 받아서 실행할 때 문제가 없으려면 같은 라이브러리를 사용할 수 있도록 해야한다.

# %%
# !pip freeze > requirements.txt
# Github에 requirements.txt를 공유함으로써 같은 환경을 공유할 수 있다.
# 같은 환경 구성을 할 수 있다.
# !pip install -r requirements.txt

# %%
from num_plus import absum
absum(1,2)
# Out:
# 3
